# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import GradientBoostingClassifier

# %%
plt.style.use('ggplot')
df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv ' , sep = ';')
X = df.drop('quality' , 1).values # drop target variable
y1 = df['quality'].values
pd.DataFrame.hist(df, figsize = [15,15]);

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
y = y1 <= 5 # is the rating <= 5?
# plot histograms of original target variable
# and aggregated target variable
plt.figure(figsize=(20,5));
plt.subplot(1, 2, 1 );
plt.hist(y1);
plt.xlabel('original target value')
plt.ylabel('count')
plt.subplot(1, 2, 2);
plt.hist(y)
plt.xlabel('aggregated target value')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from sklearn import neighbors, linear_model
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB 
        
lr = LogisticRegression(random_state=1)
knn = neighbors.KNeighborsClassifier(n_neighbors = 5)
rf = RandomForestClassifier(n_estimators=40, criterion = 'gini', random_state=1)
nb = GaussianNB()

# %%
lr_model = lr.fit(X_train, y_train)
knn_model = knn.fit(X_train, y_train)
rf_model = rf.fit(X_train, y_train)
nb_model = nb.fit(X_train, y_train)

# %%
print('k-NN accuracy for test set: %f' % knn_model.score(X_test, y_test))
print('Logistic Regression accuracy for test set: %f' % lr_model.score(X_test, y_test))
print('Random forest accuracy for test set: %f' % rf_model.score(X_test, y_test))
print('Naive Bayes accuracy for test set: %f' % nb_model.score(X_test, y_test))
# Out:
# k-NN accuracy for test set: 0.643750
# Logistic Regression accuracy for test set: 0.750000
# Random forest accuracy for test set: 0.831250
# Naive Bayes accuracy for test set: 0.743750
